# %%
# Import needed libraries
import pandas as pd
import math, datetime
import numpy as np
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib import style
import pickle
import re
from sklearn.cluster import KMeans

style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                                                   Page  Clicks  Impressions  \
# 0    https://www.beautydiaries.gr/omorfoxamos/takal...     747         8158
# 1                        https://www.beautydiaries.gr/     683         3166
# 2    https://www.beautydiaries.gr/omorfoxamos/takal...     430         3785
# 3    https://www.beautydiaries.gr/omorfoxamos/takal...     248         8620
# 4    https://www.beautydiaries.gr/omorfoxamos/takal...     135         1134
# 5    https://www.beautydiaries.gr/beauty-news-ta-ne...      90          879
# 6    https://www.beautydiaries.gr/beauty-news-ta-ne...      68         1172
# 7    https://www.beautydiaries.gr/beauty-news-ta-ne...      59          617
# 8    https://www.beautydiaries.gr/omorfoxamos/takal...      59          477
# 9    https://www.beautydiaries.gr/apopsi/tade-efi/t...      51          845
# 10   https://www.beautydiaries.gr/oraioi-anthropoi/...      49          793
# 11   https://www.beautydiaries.gr/beautynews/soma/t...      49          320
# 12   https://www.beautydiaries.gr/beauty-news-ta-ne...      47          547
# 13   https://www.beautydiaries.gr/beauty-news-ta-ne...      45          316
# 14   https://www.beautydiaries.gr/beauty-news-ta-ne...      44          597
# 15   https://www.beautydiaries.gr/omorfoxamos/takal...      40          883
# 16   https://www.beautydiaries.gr/omorfoxamos/beaut...      38          332
# 17   https://www.beautydiaries.gr/omorfoxamos/takal...      36          943
# 18   https://www.beautydiaries.gr/omorfoxamos/oikon...      36          223
# 19   https://www.beautydiaries.gr/beauty-news-ta-ne...      34          526
# 20   https://www.beautydiaries.gr/apopsi/tade-efi/c...      34          274
# 21   https://www.beautydiaries.gr/apopsi/tade-efi/t...      31          803
# 22   https://www.beautydiaries.gr/beauty-news-ta-ne...      30          306
# 23   https://www.beautydiaries.gr/omorfoxamos/takal...      29          313
# 24   https://www.beautydiaries.gr/beauty-news-ta-ne...      28          367
# 25   https://www.beautydiaries.gr/oraioi-anthropoi/...      27          604
# 26   https://www.beautydiaries.gr/beauty-news-ta-ne...      26          377
# 27   https://www.beautydiaries.gr/diagonismos/kerdi...      25         1269
# 28   https://www.beautydiaries.gr/omorfoxamos/takal...      25          821
# 29   https://www.beautydiaries.gr/omorfoxamos/oikon...      25          525
# ..                                                 ...     ...          ...
# 970  https://www.beautydiaries.gr/2010/09/08/mια-φο...       0            4
# 971       https://www.beautydiaries.gr/category/xoros/       0            4
# 972    https://www.beautydiaries.gr/tag/cream-booster/       0            4
# 973  https://www.beautydiaries.gr/category/beauty-n...       0            4
# 974  https://www.beautydiaries.gr/category/omorfoxa...       0            4
# 975  https://www.beautydiaries.gr/tag/anastasia-bev...       0            4
# 976  https://www.beautydiaries.gr/omorfoxamos/dokim...       0            4
# 977            https://www.beautydiaries.gr/tag/ypnos/       0            4
# 978  https://www.beautydiaries.gr/tag/giogka-prosopoy/       0            4
# 979  https://www.beautydiaries.gr/tag/idees-gia-mak...       0            4
# 980  https://www.beautydiaries.gr/2015/12/28/δεν-γί...       0            4
# 981  https://www.beautydiaries.gr/2015/03/08/επαναφ...       0            4
# 982       https://www.beautydiaries.gr/tag/beauty-com/       0            4
# 983  https://www.beautydiaries.gr/tag/gynaikeia-filia/       0            4
# 984  https://www.beautydiaries.gr/tag/elaia-gia-to-...       0            4
# 985       https://www.beautydiaries.gr/tag/κοπλιμέντα/       0            4
# 986          https://www.beautydiaries.gr/tag/farsali/       0            4
# 987   https://www.beautydiaries.gr/tag/schima-nychion/       0            4
# 988  https://www.beautydiaries.gr/apopsi/tade-efi/k...       0            4
# 989  https://www.beautydiaries.gr/tag/gregoris-pyrp...       0            4
# 990  https://www.beautydiaries.gr/tag/christina-fla...       0            4
# 991  https://www.beautydiaries.gr/c115d1a5ec888a953...       0            3
# 992             https://www.beautydiaries.gr/tag/blog/       0            3
# 993    https://www.beautydiaries.gr/tag/sta-farmakeia/       0            3
# 994  https://www.beautydiaries.gr/?p=15067&preview=...       0            3
# 995  https://www.beautydiaries.gr/beautynews/aroma/...       0            3
# 996   https://www.beautydiaries.gr/tag/wakupbeautiful/       0            3
# 997  https://www.beautydiaries.gr/2011/01/25/παράξε...       0            3
# 998  https://www.beautydiaries.gr/category/des-ta-p...       0            3
# 999  https://www.beautydiaries.gr/tag/voyla-sta-nyc...       0            3
#
#         CTR  Position
# 0     9.16%     21.99
# 1    21.57%     12.21
# 2    11.36%     10.81
# 3     2.88%     29.88
# 4     11.9%      9.73
# 5    10.24%     15.15
# 6      5.8%      9.70
# 7     9.56%      8.73
# 8    12.37%     16.99
# 9     6.04%      8.55
# 10    6.18%     13.74
# 11   15.31%      9.25
# 12    8.59%     15.78
# 13   14.24%     13.07
# 14    7.37%     20.63
# 15    4.53%     25.31
# 16   11.45%      9.62
# 17    3.82%     10.09
# 18   16.14%      5.08
# 19    6.46%     22.83
# 20   12.41%     17.02
# 21    3.86%     22.88
# 22     9.8%     12.08
# 23    9.27%     29.77
# 24    7.63%     26.47
# 25    4.47%     15.89
# 26     6.9%     14.86
# 27    1.97%     16.11
# 28    3.05%     31.32
# 29    4.76%     27.43
# ..      ...       ...
# 970      0%     24.25
# 971      0%     25.00
# 972      0%     28.75
# 973      0%     29.50
# 974      0%     32.00
# 975      0%     37.25
# 976      0%     38.50
# 977      0%     40.25
# 978      0%     43.50
# 979      0%     44.25
# 980      0%     47.75
# 981      0%     49.25
# 982      0%     49.75
# 983      0%     49.75
# 984      0%     53.00
# 985      0%     70.50
# 986      0%     76.75
# 987      0%     79.75
# 988      0%     81.50
# 989      0%     81.50
# 990      0%     84.75
# 991      0%      1.00
# 992      0%      1.00
# 993      0%      2.00
# 994      0%      2.33
# 995      0%      3.33
# 996      0%      4.00
# 997      0%      4.67
# 998      0%      5.33
# 999      0%      5.33
#
# [1000 rows x 5 columns]

# %%
# Cleaning The Data
df['CTR'] = df['CTR'].apply(lambda x: float(x.replace('%', '')))

# %%
X = df[['Clicks', 'Impressions', 'Position']]
y = df.pop('CTR')

# %%
# Train Test Split 
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
# Standardise The Data 
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler = scaler.fit(X_train)

# %%
X_train = pd.DataFrame(scaler.transform(X_train), columns = X_train.columns, index = X_train.index)

# %%
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns, index = X_test.index)

# %%
# Import different Algorithms to see differences between their predictions
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
Linear_regression = LinearRegression()

# %%
Linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Linear_regression.score(X_train, y_train)
# Out:
# 0.04587699725091532

# %%
Linear_regression.score(X_test, y_test)
# Out:
# -0.3732922110193282

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=50)
RandomForestRegressorModel.fit(X_train, y_train)
prediction_score = RandomForestRegressorModel.score(X_train, y_train)
test_score = RandomForestRegressorModel.score(X_test, y_test)

print(prediction_score, test_score)
# Out:
# 0.994667472140154 0.9552351062920202

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
pipeline = make_pipeline(RandomForestRegressor(n_estimators=200))
 
# Declare hyperparameters to tune
hyperparameters = { 'randomforestregressor__max_features' : ['auto', 'sqrt', 'log2'],
                  'randomforestregressor__max_depth': [5, 3, None]}
 
# Tune model using cross-validation pipeline
RandomForestRegressorModel = GridSearchCV(pipeline, hyperparameters, cv=5)
 
RandomForestRegressorModel.fit(X_train, y_train)
prediction_score = RandomForestRegressorModel.score(X_train, y_train)
print("The score of prediction for RandomForestRegressorModel is: {}".format(prediction_score))

# %% [markdown]
# ### Let's Create A Function That Combines The Predictions For X_train, X_test and also contains the index number so that we can match it back up with the original dataframe.

# %%
X_list = [X_train, X_test]
y_list = y_train, y_test

RandomForestRegressorModel = RandomForestRegressor(n_estimators=50)

data_dict = {
    
    'Indexes': [],
    'Predictions': []    
    
}

for x, y in zip(X_list, y_list):
    
    indexes = list(x.index)
    RandomForestRegressorModel.fit(X_train, y_train)
    predictions = RandomForestRegressorModel.predict(x)
    
    data_dict['Indexes'].extend(indexes)
    data_dict['Predictions'].extend(predictions)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %%
data_dict

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Merging X_train + X_test with Y_train + Y_test

# %%
merged_X = pd.concat([X_train, X_test])
merged_Y = pd.concat([y_train, y_test])

# %%
merged_df = pd.concat([merged_X, merged_Y], axis = 1)

# %%
merged_df.head(12)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Predicted Data For Click Through Ratio's For All Pages

# %%
predicted_data = pd.DataFrame(data_dict)
predicted_data.set_index(predicted_data['Indexes'], inplace = True)
predicted_data.drop(columns=['Indexes'], inplace = True)
predicted_data.rename(columns={"Predictions": "Predicted_CTR_%"}, inplace = True)

# %%
predicted_data.head(6)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Merging The Original Dataframe to the predicted CTR (%).

# %%
final_df = pd.concat([merged_df, predicted_data], axis=1)

# %%
final_df
# Out:
#        Clicks  Impressions  Position   CTR  Predicted_CTR_%
# 595 -0.133582    -0.314960  2.022484  0.00           0.0000
# 140 -0.123166     0.099501 -0.561524  0.15           0.1642
# 173 -0.128374     0.105610 -0.715761  0.07           0.0716
# 6    5.562623     3.851732 -0.269951  8.29           6.8456
# 585 -0.133582    -0.314679  0.371825  0.00           0.0000
# ..        ...          ...       ...   ...              ...
# 835 -0.133582    -0.317242 -0.314321  0.00           0.0000
# 193 -0.130110     0.083983 -0.706254  0.05           0.0550
# 316 -0.133003    -0.228662 -0.663468  0.04           0.0672
# 581 -0.133582    -0.314504 -0.694633  0.00           0.0000
# 169 -0.127796    -0.239371  1.048991  0.45           0.4082
#
# [909 rows x 5 columns]

# %%
final_df['CTR_Difference'] = final_df['Predicted_CTR_%'] - final_df['CTR']

# %%
### Now let's subset on the data and remove any CTR's that were 0.00

# %%
final_df = final_df[final_df['CTR'] != 0.00]
# Out:
#        Clicks  Impressions  Position   CTR  Predicted_CTR_%  CTR_Difference
# 140 -0.123166     0.099501 -0.561524  0.15           0.1642          0.0142
# 173 -0.128374     0.105610 -0.715761  0.07           0.0716          0.0016
# 6    5.562623     3.851732 -0.269951  8.29           6.8456         -1.4444
# 73  -0.058937     0.002530 -0.496554  1.42           1.5926          0.1726
# 145 -0.123745    -0.231015 -0.700971  0.69           0.6940          0.0040
# ..        ...          ...       ...   ...              ...             ...
# 164 -0.127217    -0.228311  1.867718  0.43           0.3766         -0.0534
# 28   0.515660     0.300499 -0.278931  6.38           5.3966         -0.9834
# 193 -0.130110     0.083983 -0.706254  0.05           0.0550          0.0050
# 316 -0.133003    -0.228662 -0.663468  0.04           0.0672          0.0272
# 169 -0.127796    -0.239371  1.048991  0.45           0.4082         -0.0418
#
# [360 rows x 6 columns]

# %%
final_df.sort_values(by='CTR_Difference', ascending=False)
# Out:
#        Clicks  Impressions  Position    CTR  Predicted_CTR_%  CTR_Difference
# 44   0.118130     0.697265 -0.255161   1.51           4.7008          3.1908
# 8    2.818098     4.847947 -0.530887   3.47           5.5242          2.0542
# 4    7.562428    11.679617 -0.099339   3.89           5.5130          1.6230
# 2    9.412364    12.421082  0.527647   4.55           6.1140          1.5640
# 350 -0.133003    -0.312081  0.465846   0.67           2.1184          1.4484
# ..        ...          ...       ...    ...              ...             ...
# 5    5.599078     3.320639 -0.486518   9.56           6.3590         -3.2010
# 40   0.196826    -0.201488 -0.559939  17.30          13.9258         -3.3742
# 30   0.424813     0.072502  0.185366   8.69           5.2566         -3.4334
# 79  -0.067038    -0.276446  0.021621   9.87           5.0988         -4.7712
# 365 -0.133003    -0.317207 -0.402532  25.00           7.0726        -17.9274
#
# [909 rows x 6 columns]

# %%
final_df = final_df[['CTR', 'Predicted_CTR_%', 'CTR_Difference']]

# %%
original_data = df[['Page', 'Clicks', 'Impressions', 'Position']]

# %%
results = pd.merge(original_data, final_df, left_index=True, right_index=True)

# %%
results.to_csv('results.csv')

# %%
results
# Out:
#                                                   Page  Clicks  Impressions  \
# 0    https://buffert.se/basta-aktierna-och-fonderna...   29585       331619
# 1                  https://buffert.se/loner-i-sverige/   19890       181742
# 2          https://buffert.se/hur-mycket-far-jag-lana/   16497       362826
# 3    https://buffert.se/basta-bankerna-privatpersoner/   13347       147683
# 4    https://buffert.se/vaxla-pengar-utomlands-bill...   13300       341707
# ..                                                 ...     ...          ...
# 904   https://buffert.se/author/svante-hansson/page/5/       0            1
# 905          https://buffert.se/rantor/#Drojsmalsranta       0            1
# 906  https://buffert.se/buffert-reser-till-japan-20...       0            1
# 907     https://buffert.se/fackforbund/#Vanliga-fragor       0            1
# 908  https://buffert.se/spartips-handla-natet/#Avsl...       0            1
#
#      Position    CTR  Predicted_CTR_%  CTR_Difference
# 0        8.86   8.92           8.2136         -0.7064
# 1        6.31  10.94           9.5772         -1.3628
# 2       26.61   4.55           6.1140          1.5640
# 3       22.57   9.04           7.5192         -1.5208
# 4       14.74   3.89           5.5130          1.6230
# ..        ...    ...              ...             ...
# 904     17.00   0.00           0.0000          0.0000
# 905     17.00   0.00           0.0000          0.0000
# 906     30.00   0.00           0.0000          0.0000
# 907     82.00   0.00           0.0000          0.0000
# 908     92.00   0.00           0.0000          0.0000
#
# [909 rows x 7 columns]
